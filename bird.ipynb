# %%
import numpy as np

from gcode_polygon import *
from gcode_origami import soft_film

# %%
mesh = 'bird_base_old'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

xbl = [np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2) for i in range (layer_count)]
xsl = [np.sqrt(h**2-(h-layer_height/2-(layer_count-i-1)*layer_height)**2) for i in range (layer_count)]
xbl[0] = 0.4

g = 0.4
k = 4.8
theta = np.pi/8
s = np.sin(theta)
c = np.cos(theta)
t = np.tan(theta)
l = 47

file = '8.20/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -l*(1+t)+g/2,2*k)

# bottom layer
_ = draw_layer(file, np.array([[-l*(1+t),2*k+2*g],[-l*(1+t),-2*k-2*g],[-l*t,-l*t-2*k-2*g],[0,-l*(1+t)-2*k-2*g],[l*t,-l*t-2*k-2*g],[l*(1+t)+k/s,-k-2*g],[l*(1+t)+k/s,k+2*g],[l*t,l*t+2*k+2*g],[0,l*(1+t)+2*k+2*g],[-l*t,l*t+2*k+2*g]]), 0.3, line_width, 0)
_ = draw_layer(file, np.array([[-l*(1+t),2*k+2*g],[-l*(1+t),-2*k-2*g],[-l*t,-l*t-2*k-2*g],[0,-l*(1+t)-2*k-2*g],[l*t,-l*t-2*k-2*g],[l*(1+t)+k/s,-k-2*g],[l*(1+t)+k/s,k+2*g],[l*t,l*t+2*k+2*g],[0,l*(1+t)+2*k+2*g],[-l*t,l*t+2*k+2*g]]), 0.7, line_width, 1)

# body
pl = np.array([[-l*(1+t),2*k+2*g],[0,2*k+2*g],[l*(1+t)/2,l*(1+t)/2*t+2*k+2*g],[l*t,l*t+2*k+2*g],[-l*t,l*t+2*k+2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xb,-xb,0,-xs,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
pl = np.array([[-l*(1+t),-2*k-2*g],[-l*t,-l*t-2*k-2*g],[l*t,-l*t-2*k-2*g],[l*(1+t)/2,-l*(1+t)/2*t-2*k-2*g],[0,-2*k-2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xs,0,-xb,-xb])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# wings
pl = np.array([[-l*t,2*k+4*g+l*t],[l*t,2*k+4*g+l*t],[0,l*(1+t)+2*k+2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xs,0,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

pl = np.array([[-l*t,-(2*k+4*g+l*t)],[0,-l*(1+t)-2*k-2*g],[l*t,-(2*k+4*g+l*t)]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,0,-xs])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# # head
pl = np.array([[l*(1+t)+k/s,k+2*g],[l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c,l*(1+t)/2*t+2*k+2*g-(2*k+4*g)*np.sqrt(2)*s],[2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s),k+2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xb,-xs])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

pl = np.array([[l*(1+t)+k/s,-(k+2*g)],[2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s),-(k+2*g)],[l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c,-(l*(1+t)/2*t+2*k+2*g-(2*k+4*g)*np.sqrt(2)*s)]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xs,-xb,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)


# middle
pl = [-l*(1+t),2*k],[-l*(1+t),-2*k],[0,-2*k],[0,2*k]
for i in range (layer_count):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xb,0,-xb])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
pl = np.array([[2*g/s,2*k+2*g],[2*g/s+2*k*np.cos(np.pi/6)/np.sin(np.pi*7/24),2*k+2*g-2*k*np.sin(np.pi/6)/np.sin(np.pi*7/24)],[l*(1+t)/2+(2*g+2*k)*np.sqrt(2)*c,l*(1+t)/2*t+2*k+2*g-(2*g+2*k)*np.sqrt(2)*s],[l*(1+t)/2+2*g*np.sqrt(2)*c,l*(1+t)/2*t+2*k+2*g-2*g*np.sqrt(2)*s]])
for i in range (layer_count):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xb,0,-xb])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
pl = np.array([[2*g/s,-(2*k+2*g)],[l*(1+t)/2+2*g*np.sqrt(2)*c,-(l*(1+t)/2*t+2*k+2*g-2*g*np.sqrt(2)*s)],[l*(1+t)/2+(2*g+2*k)*np.sqrt(2)*c,-(l*(1+t)/2*t+2*k+2*g-(2*g+2*k)*np.sqrt(2)*s)],[2*g/s+2*k*np.cos(np.pi/6)/np.sin(np.pi*7/24),-(2*k+2*g-2*k*np.sin(np.pi/6)/np.sin(np.pi*7/24))]])
for i in range (layer_count):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xb,0,-xb,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)



writ_finish_lines(file)

# %%
mesh = 'bird_top_old'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

xbl = [np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2) for i in range (layer_count)]
xsl = [np.sqrt(h**2-(h-layer_height/2-(layer_count-i-1)*layer_height)**2) for i in range (layer_count)]
xbl[0] = 0.4

g = 0.4
k = 4.8
theta = np.pi/8
s = np.sin(theta)
c = np.cos(theta)
t = np.tan(theta)
l = 50

file = '8.20/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -l*(1+t)+g/2,2*k)

# bottom layer
_ = draw_layer(file, np.array([[-l*(1+t),2*k+2*g],[-l*(1+t),-2*k-2*g],[-l*t,-l*t-2*k-2*g],[0,-l*(1+t)-2*k-2*g],[l*t,-l*t-2*k-2*g],[l*(1+t)+k/s,-k-2*g],[l*(1+t)+k/s,k+2*g],[l*t,l*t+2*k+2*g],[0,l*(1+t)+2*k+2*g],[-l*t,l*t+2*k+2*g]]), 0.3, line_width, 0)
_ = draw_layer(file, np.array([[-l*(1+t),2*k+2*g],[-l*(1+t),-2*k-2*g],[-l*t,-l*t-2*k-2*g],[0,-l*(1+t)-2*k-2*g],[l*t,-l*t-2*k-2*g],[l*(1+t)+k/s,-k-2*g],[l*(1+t)+k/s,k+2*g],[l*t,l*t+2*k+2*g],[0,l*(1+t)+2*k+2*g],[-l*t,l*t+2*k+2*g]]), 0.7, line_width, 1)

# body
pl = np.array([[-l*(1+t),2*k+2*g],[0,2*k+2*g],[l*(1+t)/2,l*(1+t)/2*t+2*k+2*g],[l*t,l*t+2*k+2*g],[-l*t,l*t+2*k+2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xs,-xs,0,-xb,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
pl = np.array([[-l*(1+t),-2*k-2*g],[-l*t,-l*t-2*k-2*g],[l*t,-l*t-2*k-2*g],[l*(1+t)/2,-l*(1+t)/2*t-2*k-2*g],[0,-2*k-2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xb,0,-xs,-xs])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# wings
pl = np.array([[-l*t,2*k+4*g+l*t],[l*t,2*k+4*g+l*t],[0,l*(1+t)+2*k+2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xb,0,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

pl = np.array([[-l*t,-(2*k+4*g+l*t)],[0,-l*(1+t)-2*k-2*g],[l*t,-(2*k+4*g+l*t)]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,0,-xb])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# head
pl = np.array([[l*(1+t)+k/s,k+2*g],[l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c,l*(1+t)/2*t+2*k+2*g-(2*k+4*g)*np.sqrt(2)*s],[2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s),k+2*g]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xs,-xb])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

pl = np.array([[l*(1+t)+k/s,-(k+2*g)],[2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s),-(k+2*g)],[l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c,-(l*(1+t)/2*t+2*k+2*g-(2*k+4*g)*np.sqrt(2)*s)]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xb,-xs,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)


# middle
pl = [2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s)+10,k],[2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s)+10,-k],[l*(1+t)+k/s,-k],[l*(1+t)+k/s,k]
for i in range (layer_count):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xb,0,-xb])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)



writ_finish_lines(file)

# %%
mesh = 'bird_base'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

xbl = [np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2) for i in range (layer_count)]
xsl = [np.sqrt(h**2-(h-layer_height/2-(layer_count-i-1)*layer_height)**2) for i in range (layer_count)]
xbl[0] = 0.4

x1 = 15
x2 = 20
x3 = 16
x4 = 10
x5 = 8

y1 = 25
y2 = 15.2
y3 = 10
y4 = 8
y5 = 4

k = 8
g = 0.4
l = 9.6

file = '8.20/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -x1,-(y3+k+g*4))

# bottom layer

# [-x1,-(y3+k+g*4)],[-x5,-(y2+k+g*4)],[-x5,-(y2+k*2+g*8+l)],[0,-(y1+k*2+g*8+l)],[x5,-(y2+k*2+g*8+l)],[x5,-(y2+k+g*4)],[x4,-(y3+k+g*4)],[x4,-y3],[x4+k+g*4,-y3],[x3+k+g*4,-y4],[x3+k*2+g*8,-y4],[x2+k*2+g*8,-y5],[x2+k*2+g*8,y5],[x3+k*2+g*8,y4],[x3+k+g*4,y4],[x4+k+g*4,y3],[x4,y3],[x4,y3+k+g*4],[x5,y2+k+g*4],[x5,y2+k*2+g*8+l],[0,y1+k*2+g*8+l],[-x5,y2+k*2+g*8+l],[-x5,y2+k+g*4],[-x1,y3+k+g*4]

p1 = np.array([-x1,-(y3+k+g*4)])
p2 = np.array([-x5,-(y2+k+g*4)])
p3 = np.array([-x5+0.1,-(y2+k*2+g*8+l)])
p4 = np.array([0,-(y1+k*2+g*8+l)])
p5 = np.array([x5-0.1,-(y2+k*2+g*8+l)])
p6 = np.array([x5,-(y2+k+g*4)])
p7 = np.array([x4,-(y3+k+g*4)])
p8 = np.array([x4,-y3])
p9 = np.array([x4+k+g*4,-y3])
p10 = np.array([x3+k+g*4,-y4])
p11 = np.array([x3+k*2+g*8,-y4])
p12 = np.array([x2+k*2+g*8,-y5])
p13 = np.array([x2+k*2+g*8,y5])
p14 = np.array([x3+k*2+g*8,y4])
p15 = np.array([x3+k+g*4,y4])
p16 = np.array([x4+k+g*4,y3])
p17 = np.array([x4,y3])
p18 = np.array([x4,y3+k+g*4])
p19 = np.array([x5,y2+k+g*4])
p20 = np.array([x5-0.1,y2+k*2+g*8+l])
p21 = np.array([0,y1+k*2+g*8+l])
p22 = np.array([-x5+0.1,y2+k*2+g*8+l])
p23 = np.array([-x5,y2+k+g*4])
p24 = np.array([-x1,y3+k+g*4])

pl = np.array([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18,p19,p20,p21,p22,p23,p24])

_ = draw_layer(file, pl, 0.3, line_width, 0)
_ = draw_layer(file, pl, 0.7, line_width, 1)

# body
pl = np.array([[-x1,-y3-k/2],[x4,-y3-k/2],[x4,-y3],[x4+k/2,-y3],[x4+k/2,y3],[x4,y3],[x4,y3+k/2],[-x1,y3+k/2]])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([-xb,0,0,-xb,0,0,-xb,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
pl = np.array([p1+np.array([0,k/2]),p1,p2,p2-np.array([0,k/2]),p6-np.array([0,k/2]),p6,p7,p7+np.array([0,k/2])])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,0,-xb,0,0,0,-xb,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
pl = np.array([p24,p24-np.array([0,k/2]),p18-np.array([0,k/2]),p18,p19,p19+np.array([0,k/2]),p23+np.array([0,k/2]),p23])
for i in range (layer_count//2):
    xb = xbl[i]
    xs = xsl[i]
    ml = np.array([0,-xb,0,0,0,-xb,0,0])
    pl_new = side_move_inside(pl,ml)
    if i == 0:
        move_to(file,pl_new[0][0],pl_new[0][1],1.1)
    _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# # wings
# pl = np.array([[-l*t,2*k+4*g+l*t],[l*t,2*k+4*g+l*t],[0,l*(1+t)+2*k+2*g]])
# for i in range (layer_count//2):
#     xb = xbl[i]
#     xs = xsl[i]
#     ml = np.array([-xs,0,0])
#     pl_new = side_move_inside(pl,ml)
#     if i == 0:
#         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
#     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# pl = np.array([[-l*t,-(2*k+4*g+l*t)],[0,-l*(1+t)-2*k-2*g],[l*t,-(2*k+4*g+l*t)]])
# for i in range (layer_count//2):
#     xb = xbl[i]
#     xs = xsl[i]
#     ml = np.array([0,0,-xs])
#     pl_new = side_move_inside(pl,ml)
#     if i == 0:
#         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
#     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# # # head
# pl = np.array([[l*(1+t)+k/s,k+2*g],[l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c,l*(1+t)/2*t+2*k+2*g-(2*k+4*g)*np.sqrt(2)*s],[2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s),k+2*g]])
# for i in range (layer_count//2):
#     xb = xbl[i]
#     xs = xsl[i]
#     ml = np.array([0,-xb,-xs])
#     pl_new = side_move_inside(pl,ml)
#     if i == 0:
#         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
#     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)

# pl = np.array([[l*(1+t)+k/s,-(k+2*g)],[2*(l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c)-(l*(1+t)+k/s),-(k+2*g)],[l*(1+t)/2+(2*k+4*g)*np.sqrt(2)*c,-(l*(1+t)/2*t+2*k+2*g-(2*k+4*g)*np.sqrt(2)*s)]])
# for i in range (layer_count//2):
#     xb = xbl[i]
#     xs = xsl[i]
#     ml = np.array([-xs,-xb,0])
#     pl_new = side_move_inside(pl,ml)
#     if i == 0:
#         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
#     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)


# # middle
# pl = [-l*(1+t),2*k],[-l*(1+t),-2*k],[0,-2*k],[0,2*k]
# for i in range (layer_count):
#     xb = xbl[i]
#     xs = xsl[i]
#     ml = np.array([0,-xb,0,-xb])
#     pl_new = side_move_inside(pl,ml)
#     if i == 0:
#         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
#     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
# pl = np.array([[2*g/s,2*k+2*g],[2*g/s+2*k*np.cos(np.pi/6)/np.sin(np.pi*7/24),2*k+2*g-2*k*np.sin(np.pi/6)/np.sin(np.pi*7/24)],[l*(1+t)/2+(2*g+2*k)*np.sqrt(2)*c,l*(1+t)/2*t+2*k+2*g-(2*g+2*k)*np.sqrt(2)*s],[l*(1+t)/2+2*g*np.sqrt(2)*c,l*(1+t)/2*t+2*k+2*g-2*g*np.sqrt(2)*s]])
# for i in range (layer_count):
#     xb = xbl[i]
#     xs = xsl[i]
#     ml = np.array([0,-xb,0,-xb])
#     pl_new = side_move_inside(pl,ml)
#     if i == 0:
#         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
#     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
    
# pl = np.array([[2*g/s,-(2*k+2*g)],[l*(1+t)/2+2*g*np.sqrt(2)*c,-(l*(1+t)/2*t+2*k+2*g-2*g*np.sqrt(2)*s)],[l*(1+t)/2+(2*g+2*k)*np.sqrt(2)*c,-(l*(1+t)/2*t+2*k+2*g-(2*g+2*k)*np.sqrt(2)*s)],[2*g/s+2*k*np.cos(np.pi/6)/np.sin(np.pi*7/24),-(2*k+2*g-2*k*np.sin(np.pi/6)/np.sin(np.pi*7/24))]])
# for i in range (layer_count):
#     xb = xbl[i]
#     xs = xsl[i]
#     ml = np.array([-xb,0,-xb,0])
#     pl_new = side_move_inside(pl,ml)
#     if i == 0:
#         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
#     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)



# writ_finish_lines(file)
# Out:
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py:101: RuntimeWarning: divide by zero encountered in true_divide
#   xm = (x1 + x2) / np.linalg.norm(x1 + x2) * w / np.sin(theta)
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py:101: RuntimeWarning: invalid value encountered in true_divide
#   xm = (x1 + x2) / np.linalg.norm(x1 + x2) * w / np.sin(theta)
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py:42: RuntimeWarning: invalid value encountered in add
#   xy += [delta_x, delta_y]
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py:79: RuntimeWarning: invalid value encountered in true_divide
#   x1 = sl[0] / np.linalg.norm(sl[0])
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py:80: RuntimeWarning: invalid value encountered in true_divide
#   x2 = - sl[-1] / np.linalg.norm(sl[-1])
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py:83: RuntimeWarning: invalid value encountered in true_divide
#   x2 = - sl[i-1] / np.linalg.norm(sl[i-1])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\qy_la\AppData\Local\Temp\ipykernel_12536\2415934116.py in <module>
#      82     if i == 0:
#      83         move_to(file,pl_new[0][0],pl_new[0][1],1.1)
# ---> 84     _ = draw_layer(file, pl_new, 1.1+i*layer_height, line_width, 0)
#      85
#      86 pl = np.array([p24,p24-np.array([0,k/2]),p18-np.array([0,k/2]),p18,p19,p19+np.array([0,k/2]),p23+np.array([0,k/2]),p23])
#
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py in draw_layer(file, point_list, z, w, direction, extra_line)
#     265
#     266     if direction == 0:
# --> 267         pl = draw_layer_out_in(file, point_list, z, w, extra_line)
#     268     elif direction == 1:
#     269         pl = draw_layer_in_out(file, point_list, z, w, extra_line)
#
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py in draw_layer_out_in(file, pl, z, w, extra_line)
#     173             xy, lines = write_G1_line(sv[i][0], sv[i][1], xy, lines)
#     174
# --> 175         pl = polygon_inside_move(pl, w)
#     176
#     177         while(1):
#
# e:\200_research\summer2024@sutd\gcode\gcode_polygon.py in polygon_inside_move(pl, w)
#     103                 pl_new = pl[i] - xm
#     104             else:
# --> 105                 pl_new = np.vstack((pl_new, pl[i] - xm))
#     106     # print(pl_new)
#     107     return pl_new
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# c:\Downloads\Anaconda3\envs\didl\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     280     if not isinstance(arrs, list):
#     281         arrs = [arrs]
# --> 282     return _nx.concatenate(arrs, 0)
#     283
#     284
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 0 and the array at index 1 has size 2
