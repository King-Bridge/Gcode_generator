# %%
import numpy as np

from gcode_polygon import *
from gcode_origami import soft_film

# %%
mesh = 'top_cross_previous'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.10/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -23.8, 0)

# bottom cross
draw_layer(file, np.array([[-23.8,0],[-23.8,-5],[-5,-5],[-5,-23.8],[5,-23.8],[5,-5],[42.6,-5],
                           [42.6,5],[23.8,5],[23.8,23.8],[13.8,23.8],[13.8,5],[-23.8,5]]), 0.3, line_width, 0)
draw_layer(file, np.array([[-23.8,0],[-23.8,-5],[-5,-5],[-5,-23.8],[5,-23.8],[5,-5],[42.6,-5],
                           [42.6,5],[23.8,5],[23.8,23.8],[13.8,23.8],[13.8,5],[-23.8,5]]), 0.7, line_width, 1, extra_line=1)

    
# 2 half platforms
move_to(file, -9, 0, 1.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2)
    xs = layer_height/2+(layer_count-i)*layer_height
    draw_layer(file, np.array([[-9+xb,0],[-9+xb,-9+xb],[9-xb,-9+xb],
                               [9-xb,9-xs],[-9+xb,9-xs]]), i*layer_height + 1.1, line_width, i%2)
    
move_to(file, 13.8, 0, 1.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2)
    xs = layer_height/2+(layer_count-i)*layer_height
    draw_layer(file, np.array([[9.8+xb,0],[9.8+xb,-9+xs],[27.8-xb,-9+xs],
                               [27.8-xb,9-xb],[9.8+xb,9-xb]]), i*layer_height + 1.1, line_width, i%2)
    
    
writ_finish_lines(file)

# %%
mesh = 'base_cross_previous'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.10/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -27.8, 0)

# bottom cross
draw_layer(file, np.array([[-27.8-0.8,0],[-27.8-0.8,-9-0.8],[-9.8,-9-0.8],
                           [-9.8,9+0.8],[-27.8-0.8,9+0.8]]), 0.3, line_width, 0)
draw_layer(file, np.array([[-27.8-0.4,0],[-27.8-0.4,-9-0.4],[-9.8,-9-0.4],
                           [-9.8,9+0.4],[-27.8-0.4,9+0.4]]), 0.7, line_width, 1)

move_to(file, -9, 0, 0.3)
draw_layer(file, np.array([[-9,0],[-9,-9-0.8],[9,-9-0.8],[9,9],[-9,9]]), 0.3, line_width, 0)
draw_layer(file, np.array([[-9,0],[-9,-9-0.4],[9,-9-0.4],[9,9],[-9,9]]), 0.7, line_width, 1)

move_to(file, 9.8, 0, 0.3)
draw_layer(file, np.array([[9.8,0],[9.8,-9],[27.8,-9],[27.8,9+0.8],[9.8,9+0.8]]), 0.3, line_width, 0)
draw_layer(file, np.array([[9.8,0],[9.8,-9],[27.8,-9],[27.8,9+0.4],[9.8,9+0.4]]), 0.7, line_width, 1)

move_to(file, 0, 27.8, 0.3)
draw_layer(file, np.array([[0,27.8+0.8],[-9-0.8,27.8+0.8],[-9-0.8,9.8],
                           [9+0.8,9.8],[9+0.8,27.8+0.8]]), 0.3, line_width, 0)
draw_layer(file, np.array([[0,27.8+0.4],[-9-0.4,27.8+0.4],[-9-0.4,9.8],
                           [9+0.4,9.8],[9+0.4,27.8+0.4]]), 0.7, line_width, 1)

move_to(file, 18.8, -27.8, 0.3)
draw_layer(file, np.array([[18.8,-27.8-0.8],[27.8+0.8,-27.8-0.8],[27.8+0.8,-9.8],
                           [9.8-0.8,-9.8],[9.8-0.8,-27.8-0.8]]), 0.3, line_width, 0)
draw_layer(file, np.array([[18.8,-27.8-0.4],[27.8+0.4,-27.8-0.4],[27.8+0.4,-9.8],
                           [9.8-0.4,-9.8],[9.8-0.4,-27.8-0.4]]), 0.7, line_width, 1)

move_to(file, 46.6, 0, 0.3)
draw_layer(file, np.array([[46.6+0.8,0],[46.6+0.8,9+0.8],[28.6,9+0.8],
                           [28.6,-9-0.8],[46.6+0.8,-9-0.8]]), 0.3, line_width, 0)
draw_layer(file, np.array([[46.6+0.4,0],[46.6+0.4,9+0.4],[28.6,9+0.4],
                           [28.6,-9-0.4],[46.6+0.4,-9-0.4]]), 0.7, line_width, 1)

move_to(file, -27.8, 0, 1.1)
draw_layer(file, np.array([[-27.8,0],[-27.8,-9],[9.8,-9],[9.8,-27.8],[27.8,-27.8],[27.8,-9],[46.6,-9],
                           [46.6,9],[9,9],[9,27.8],[-9,27.8],[-9,9],[-27.8,9]]), 1.1, line_width, 0, extra_line=2)

# 4 full platforms
move_to(file, -27.8, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    draw_layer(file, np.array([[-27.8+xs,0],[-27.8+xs,-9+xs],[-9.8-xb,-9+xs],
                               [-9.8-xb,9-xs],[-27.8+xs,9-xs]]), i*layer_height + 1.5, line_width, i%2)
    
move_to(file, 0, 27.8, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    draw_layer(file, np.array([[0,27.8-xs],[-9+xs,27.8-xs],[-9+xs,9.8+xb],
                               [9-xs,9.8+xb],[9-xs,27.8-xs]]), i*layer_height + 1.5, line_width, i%2)
    
move_to(file, 18.8, -27.8, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    draw_layer(file, np.array([[18.8,-27.8+xs],[27.8-xs,-27.8+xs],[27.8-xs,-9.8-xb],
                               [9.8+xs,-9.8-xb],[9.8+xs,-27.8+xs]]), i*layer_height + 1.5, line_width, i%2)
    
move_to(file, 46.6, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    draw_layer(file, np.array([[46.6-xs,0],[46.6-xs,9-xs],[28.6+xb,9-xs],
                               [28.6+xb,-9+xs],[46.6-xs,-9+xs]]), i*layer_height + 1.5, line_width, i%2)
    
# 2 half platforms
move_to(file, -9, 0, 1.5)
for i in range (layer_count-6):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    draw_layer(file, np.array([[-9+xb,0],[-9+xb,-9+xs],[9-xb,-9+xs],
                               [9-xb,9-xb],[-9+xb,9-xb]]), i*layer_height + 1.5, line_width, i%2)
move_to(file, -0.6, 0.6, 1.5)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    xs = layer_height/2+(i+layer_count-6)*layer_height
    draw_layer(file, np.array([[-0.6,0.6],[-0.6,9-xb],
                               [-9+xb,9-xb],[-9+xb,0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2)
move_to(file, 0.6, 0.6, 1.5)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    xs = layer_height/2+(i+layer_count-6)*layer_height
    draw_layer(file, np.array([[0.6,0.6],[9-xb,0.6],
                               [9-xb,9-xb],[0.6,9-xb]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2)
move_to(file, -5.5, -0.6, 1.5)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    xs = layer_height/2+(i+layer_count-6)*layer_height
    draw_layer(file, np.array([[-9+xb,-0.6],[-9+xb,-9+xs],
                               [9-xb,-9+xs],[9-xb,-0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2)
    
move_to(file, 9.8, 0, 1.5)
for i in range (layer_count-6):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    draw_layer(file, np.array([[9.8+xb,0],[9.8+xb,-9+xb],[27.8-xb,-9+xb],
                               [27.8-xb,9-xs],[9.8+xb,9-xs]]), i*layer_height + 1.5, line_width, i%2)
move_to(file, 19.4, -0.6, 1.5)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    xs = layer_height/2+(i+layer_count-6)*layer_height
    draw_layer(file, np.array([[19.4,-0.6],[19.4,-9+xb],
                               [27.8-xb,-9+xb],[27.8-xb,-0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2)
move_to(file, 18.2, -0.6, 1.5)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    xs = layer_height/2+(i+layer_count-6)*layer_height
    draw_layer(file, np.array([[18.2,-0.6],[9.8+xb,-0.6],
                               [9.8+xb,-9+xb],[18.2,-9+xb]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2)
move_to(file, 24.3, 0.6, 1.5)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    xs = layer_height/2+(i+layer_count-6)*layer_height
    draw_layer(file, np.array([[27.8-xb,0.6],[27.8-xb,9-xs],
                               [9.8+xb,9-xs],[9.8+xb,0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2)
    

writ_finish_lines(file)

# %%
mesh = 'side'
layer_height = 0.4
line_width = 0.4
layer_count = 1
length_a = 30
length_b = 8
wall_layer_count = 0
file = '8.14/'+mesh+'_'+str(length_a)+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -length_a/2, -length_b/2)

lines = []
w = line_width
xy = np.array([-length_a/2+w/2, -length_b/2+w/2])
write_init_layer(xy, 0.3, lines)
for i in range (int(length_b/w)):
    xb = i*w/np.sqrt(2)
    if i%2 == 0:
        xy, lines = write_G1_line(length_a-w, 0, xy, lines)
        # xy, lines = write_G1_line(w/np.sqrt(2), w, xy, lines)
        xy, lines = write_G1_line(0, w, xy, lines)
    else:
        xy, lines = write_G1_line(-length_a+w, 0, xy, lines)
        # xy, lines = write_G1_line(w/np.sqrt(2), w, xy, lines)
        xy, lines = write_G1_line(0, w, xy, lines)
        
with open(file, 'a') as f:
    f.writelines(lines)
        
writ_finish_lines(file)

# %%
mesh = 'base_cross'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.13/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -47.7, 0)

# bottom cross
draw_layer(file, np.array([[-47.9,0],[-47.9,-8],[-26.9,-8],[-26.9,8],[-47.9,8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[-47.9,0],[-47.9,-8],[-26.9,-8],[-26.9,8],[-47.9,8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, -26.1, 0, 0.3)
draw_layer(file, np.array([[-26.3,0],[-26.3,-8],[-0.3,-8],[-0.3,8],[-5.3,8],
                           [-5.3,13],[-21.3,13],[-21.3,8],[-26.3,8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[-26.3,0],[-26.3,-8],[-0.3,-8],[-0.3,8],[-5.3,8],
                           [-5.3,13],[-21.3,13],[-21.3,8],[-26.3,8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, 26.1, 0, 0.3)
draw_layer(file, np.array([[26.3,0],[26.3,8],[0.3,8],[0.3,-8],[5.3,-8],
                           [5.3,-13],[21.3,-13],[21.3,-8],[26.3,-8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[26.3,0],[26.3,8],[0.3,8],[0.3,-8],[5.3,-8],
                           [5.3,-13],[21.3,-13],[21.3,-8],[26.3,-8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, 47.7, 0, 0.3)
draw_layer(file, np.array([[47.9,0],[47.9,8],[26.9,8],[26.9,-8],[47.9,-8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[47.9,0],[47.9,8],[26.9,8],[26.9,-8],[47.9,-8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, -13.3, 13.8, 0.3)
draw_layer(file, np.array([[-13.3,13.6],[-5.3,13.6],[-5.3,34.6],
                           [-21.3,34.6],[-21.3,13.6]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[-13.3,13.6],[-5.3,13.6],[-5.3,34.6],
                           [-21.3,34.6],[-21.3,13.6]]), 0.7, line_width, 1, extra_line=1)

move_to(file, 13.3, -13.8, 0.3)
draw_layer(file, np.array([[13.3,-13.6],[5.3,-13.6],[5.3,-34.6],
                           [21.3,-34.6],[21.3,-13.6]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[13.3,-13.6],[5.3,-13.6],[5.3,-34.6],
                           [21.3,-34.6],[21.3,-13.6]]), 0.7, line_width, 1, extra_line=1)

move_to(file, -47.7, 0, 1.1)
draw_layer(file, np.array([[-47.9,0],[-47.9,-8],[5.3,-8],[5.3,-34.6],[21.3,-34.6],[21.3,-8],[47.9,-8],[47.9,8],
                           [-5.3,8],[-5.3,34.6],[-21.3,34.6],[-21.3,8],[-47.9,8]]), 1.1, line_width, 0, extra_line=1)

# 4 full platforms
move_to(file, -47.7, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i < 8:
        draw_layer(file, np.array([[-47.9,0],[-47.9,-8],[-26.9-xb,-8],
                               [-26.9-xb,8],[-47.9,8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[-47.9,0],[-47.9,-8],[-26.9-xb,-8],
                               [-26.9-xb,8],[-47.9,8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, -13.3, 34.4, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    if i < 8:
        draw_layer(file, np.array([[-13.3,34.6],[-21.3,34.6],[-21.3,13.6+xb],
                               [-5.3,13.6+xb],[-5.3,34.6]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[-13.3,34.6],[-21.3,34.6],[-21.3,13.6+xb],
                               [-5.3,13.6+xb],[-5.3,34.6]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, 13.3, -34.4, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    if i < 8:
        draw_layer(file, np.array([[13.3,-34.6],[21.3,-34.6],[21.3,-13.6-xb],
                               [5.3,-13.6-xb],[5.3,-34.6]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[13.3,-34.6],[21.3,-34.6],[21.3,-13.6-xb],
                               [5.3,-13.6-xb],[5.3,-34.6]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, 47.7, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i < 8:
        draw_layer(file, np.array([[47.9,0],[47.9,8],[26.9+xb,8],
                               [26.9+xb,-8],[47.9,-8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[47.9,0],[47.9,8],[26.9+xb,8],
                               [26.9+xb,-8],[47.9,-8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
# 2 half platforms
move_to(file, -26.1, 0, 1.5)
for i in range (layer_count-6):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[-26.3+xb,0],[-26.3+xb,-8],[-0.3-xb,-8],[-0.3-xb,8],[-5.3,8],[-5.3,13-xb],
                               [-21.3,13-xb],[-21.3,8],[-26.3+xb,8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
move_to(file, -14.1, 0.8, 3.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    draw_layer(file, np.array([[-13.9,0.6],[-13.9,13-xb],[-21.3,13-xb],[-21.3,8],[-26.3+xb,8],
                               [-26.3+xb,0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, -12.5, 0.8, 3.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    draw_layer(file, np.array([[-12.7,0.6],[-0.3-xb,0.6],[-0.3-xb,8],[-5.3,8],[-5.3,13-xb],
                               [-12.7,13-xb]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, -13.3, -0.8, 3.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    draw_layer(file, np.array([[-13.3,-0.6],[-26.3+xb,-0.6],[-26.3+xb,-8],[-0.3-xb,-8],
                               [-0.3-xb,-0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, 26.1, 0, 1.5)
for i in range (layer_count-6):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[26.3-xb,0],[26.3-xb,8],[0.3+xb,8],[0.3+xb,-8],[5.3,-8],[5.3,-13+xb],
                               [21.3,-13+xb],[21.3,-8],[26.3-xb,-8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
move_to(file, 14.1, -0.8, 3.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    draw_layer(file, np.array([[13.9,-0.6],[13.9,-13+xb],[21.3,-13+xb],[21.3,-8],[26.3-xb,-8],
                               [26.3-xb,-0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, 12.5, -0.8, 3.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    draw_layer(file, np.array([[12.7,-0.6],[0.3+xb,-0.6],[0.3+xb,-8],[5.3,-8],[5.3,-13+xb],
                               [12.7,-13+xb]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, 13.3, 0.8, 3.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-6)*layer_height)**2)
    draw_layer(file, np.array([[13.3,0.6],[26.3-xb,0.6],[26.3-xb,8],[0.3+xb,8],
                               [0.3+xb,0.6]]), (i+layer_count-6)*layer_height + 1.5, line_width, i%2, extra_line=0)
    

    

writ_finish_lines(file)

# %%
mesh = 'top_cross'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.12/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -47.7, 0)

# bottom cross
draw_layer(file, np.array([[-47.9,0],[-47.9,-8],[-21.3,-8],[-21.3,-34.6],[-5.3,-34.6],[-5.3,-8],[47.9,-8],
                           [47.9,8],[21.3,8],[21.3,34.6],[5.3,34.6],[5.3,8],[-47.9,8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[-47.9,0],[-47.9,-8],[-21.3,-8],[-21.3,-34.6],[-5.3,-34.6],[-5.3,-8],[47.9,-8],
                           [47.9,8],[21.3,8],[21.3,34.6],[5.3,34.6],[5.3,8],[-47.9,8]]), 0.7, line_width, 1, extra_line=1)

    
# 2 half platforms
move_to(file, -22.1, 0, 1.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2)
    draw_layer(file, np.array([[-26.3+xb,0],[-26.3+xb,-8],[-21.3,-8],[-21.3,-13+xb],[-5.3,-13+xb],
                               [-5.3,-8],[-0.3-xb,-8],[-0.3-xb,8],[-26.3+xb,8]]), i*layer_height + 1.1, line_width, i%2)

move_to(file, 22.1, 0, 1.1)
for i in range (3):
    xb = np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2)
    draw_layer(file, np.array([[26.3-xb,0],[26.3-xb,8],[21.3,8],[21.3,13-xb],[5.3,13-xb],
                               [5.3,8],[0.3+xb,8],[0.3+xb,-8],[26.3-xb,-8]]), i*layer_height + 1.1, line_width, i%2)
    
    
writ_finish_lines(file)

# %%
mesh = 'film'
layer_height = 0.4
line_width = 0.4
layer_count = 2
length_a = 20.0
length_b = 22.0
wall_layer_count = 0
file = '8.16/film_'+str(length_a)+'_'+str(length_b)+'.gcode'
write_header_lines(file, layer_height, 0.4, layer_count, mesh, -length_a/2, -length_b/2+line_width/2)

soft_film(file, np.array([-length_a/2, -length_b/2]), np.array([length_a/2, length_b/2]), line_width, layer_height, layer_count=2)
        
writ_finish_lines(file)

# %%
mesh = 'twist_half_short'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.17/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -16.8, 0)

xo = 1.0
x1 = 7
x2 = 20
w = line_width

xbl = [np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2) for i in range (layer_count)]
xsl = [np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2) for i in range (layer_count)]
xbl[0] = 0.4

# bottom film
draw_layer(file, np.array([[-x2,0],[-x2,-10],[-(x1+xo),-10],[-(x1+xo),10],[-x2,10]]), 0.3, line_width, 0)

move_to(file, x2-w/2, 0, 0.3)
draw_layer(file, np.array([[x2,0],[x2,10],[-x1,10],[-x1,-10],[x2,-10]]), 0.3, line_width, 0)

move_to(file, -(x2-w/2), -9.8, 0.7)

soft_film(file, np.array([-20.0,-10]), np.array([20.0,10]), line_width, layer_height, z=0.7)

# 1 full platforms
move_to(file, -x2+w/2, 0, 1.1)
for i in range (layer_count):
    # xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xb = xbl[i]
    draw_layer(file, np.array([[-x2,0],[-x2,-10],[-(x1+xo)-xb,-10],[-(x1+xo)-xb,10],[-x2,10]]), 
               i*layer_height + 1.1, line_width, i%2)
  
# 1 half platforms
move_to(file, (x1+xo)-5, 0, 1.1)
for i in range (layer_count-7):
    # xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    # xs = np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2)
    xb = xbl[i]
    xs = xsl[i]
    draw_layer(file, np.array([[x1-xs,0],[x1-xs,10],[-x1+xb,10],[-x1+xb,-10],[x1-xs,-10]]), 
               i*layer_height + 1.1, line_width, i%2)
move_to(file, 0, 1.0, 2.3)
for i in range (2):
    # xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    # xs = np.sqrt(h**2-(h-layer_height/2-(layer_count-(i+layer_count-7))*layer_height)**2)
    xb = xbl[i+3]
    xs = xsl[i+3]
    draw_layer(file, np.array([[0,0.8],[x1-xs,0.8],[x1-xs,10],[-x1+xb,10],[-x1+xb,0.8]]), 
               (i+layer_count-7)*layer_height + 1.1, line_width, i%2)
    
move_to(file, 0, -1.0, 2.3)
for i in range (2):
    # xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    # xs = np.sqrt(h**2-(h-layer_height/2-(layer_count-(i+layer_count-7))*layer_height)**2)
    xb = xbl[i+3]
    xs = xsl[i+3]
    draw_layer(file, np.array([[0,-0.8],[-x1+xb,-0.8],[-x1+xb,-10],[x1-xs,-10],[x1-xs,-0.8]]), 
               (i+layer_count-7)*layer_height + 1.1, line_width, i%2)

writ_finish_lines(file)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
mesh = 'base_double_together'
layer_height = 0.4
line_width = 0.4
height = 4
layer_count = int(height/layer_height)

x0 = 4.8
x1 = x0 + 1.0
x2 = 17
xo = -0.25

y1 = 0.1
y2 = 10

file = '8.14/'+mesh+'_'+str(x2)+'_'+str(y2)+'_'+str(x0)+'_'+f'{(x1-x0)/2:.2f}'+'_'+str(height)+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -x2+0.2, 0)

h = height
draw_layer(file, np.array([[-x2,0],[-x2,-y2],[-x1,-y2],[-x1,y2],[-x2,y2]]), 0.3, line_width, False)
draw_layer(file, np.array([[-x2,0],[-x2,-y2],[-x1,-y2],[-x1,y2],[-x2,y2]]), 0.7, line_width, True)
move_to(file, -x0+line_width/2, 0, 0.3)
draw_layer(file, np.array([[-x0,0],[-x0,-y2],[x0,-y2],[x0,y2],[-x0,y2]]), 0.3, line_width, False)
draw_layer(file, np.array([[-x0,0],[-x0,-y2],[x0,-y2],[x0,y2],[-x0,y2]]), 0.7, line_width, True)
move_to(file, x2-line_width/2, 0, 0.3)
draw_layer(file, np.array([[x2,0],[x2,y2],[x1,y2],[x1,-y2],[x2,-y2]]), 0.3, line_width, False)
draw_layer(file, np.array([[x2,0],[x2,y2],[x1,y2],[x1,-y2],[x2,-y2]]), 0.7, line_width, True)
move_to(file, -x2+line_width/2, -y2, 1.1)
soft_film(file, np.array([float(-x2),float(-y2)]), np.array([float(x2),float(y2)]), line_width, layer_height, z=1.1)

move_to(file, -x2+line_width/2, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[-x2,0],[-x2,-y2],[-x1-xb,-y2],
                               [-x1-xb,y2],[-x2,y2]]), i*layer_height + 1.5, line_width, i%2)

move_to(file, x2-line_width/2, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[x2,0],[x2,y2],[x1+xb,y2],
                               [x1+xb,-y2],[x2,-y2]]), i*layer_height + 1.5, line_width, i%2)

move_to(file, -x0+line_width/2, -y1, 1.5)
for i in range (layer_count-7):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[-x0+xb,0],[-x0+xb,-y2],[x0-xb,-y2],[x0-xb,y2],[-x0+xb,y2]]), 
               i*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
move_to(file, 0, 1.0, 1.5)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[0,0.8],[x0-xb,0.8],[x0-xb,y2],[-x0+xb,y2],[-x0+xb,0.8]]), 
               (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
move_to(file, 0, -1.0, 2.7)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[0,-0.8],[-x0+xb,-0.8],[-x0+xb,-y2],[x0-xb,-y2],[x0-xb,-0.8]]), 
               (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
move_to(file, 0, 0, 4.3)
for i in range (layer_count-7):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-3)*layer_height)**2)
    draw_layer(file, np.array([[-x0+xb,0],[-x0+xb,-y2],[x0-xb,-y2],[x0-xb,y2],[-x0+xb,y2]]), 
               (i+layer_count-3)*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))

    
        
writ_finish_lines(file)

# %%
mesh = 'with_wall'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.14/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -11.8, 0)

# bottom film
draw_layer(file, np.array([[-12,0],[-12,-10],[-0.3,-10],[-0.3,10],[-12,10]]), 0.3, line_width, 0)
draw_layer(file, np.array([[-12,0],[-12,-10],[-0.3,-10],[-0.3,10],[-12,10]]), 0.7, line_width, 1, extra_line=1)

move_to(file, 11.8, 0, 0.3)
draw_layer(file, np.array([[12,0],[12,10],[0.3,10],[0.3,-10],[12,-10]]), 0.3, line_width, 0)
draw_layer(file, np.array([[12,0],[12,10],[0.3,10],[0.3,-10],[12,-10]]), 0.7, line_width, 1, extra_line=1)

move_to(file, -11.8, -9.8, 1.1)
soft_film(file, np.array([-12.0,-9.8]), np.array([12.0,9.8]), line_width, layer_height, z=1.1)

# 2 full platforms
move_to(file, -11.8, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[-12,0],[-12,-10],[-0.3-xb,-10],[-0.3-xb,10],[-12,10]]), 
               i*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
move_to(file, 11.8, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[12,0],[12,10],[0.3+xb,10],[0.3+xb,-10],[12,-10]]), 
               i*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
  
# side walls
xo = 1.2
move_to(file, 1.55+xo, -9.8, 1.5)
lines = []
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    lines.append(f'G1 X{(-0.3-xo-xb)*np.sign(i%2-0.5):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
    lines.append(f'G1 X{(0.3+xo+xb)*np.sign(i%2-0.5):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
with open(file, 'a') as f:
    f.writelines(lines)
    
move_to(file, 1.55+xo, 9.8, 1.5)
lines = []
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    lines.append(f'G1 X{(-0.3-xo-xb)*np.sign(i%2-0.5):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
    lines.append(f'G1 X{(0.3+xo+xb)*np.sign(i%2-0.5):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
with open(file, 'a') as f:
    f.writelines(lines)


writ_finish_lines(file)

# %%
mesh = 'base_double_with_wall'
layer_height = 0.4
line_width = 0.4
height = 4
layer_count = int(height/layer_height)

x0 = 4.8
x1 = x0 + 0.8
x2 = 20
xo = -0.25

y1 = 0.1
y2 = 10

xbl = [np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2) for i in range (layer_count)]
xsl = [np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2) for i in range (layer_count)]
xbl[0] = 0.4

file = '8.15/'+mesh+'_'+str(x2)+'_'+str(y2)+'_'+str(x0)+'_'+f'{(x1-x0)/2:.2f}'+'_'+str(height)+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -x2+0.2, 0)

h = height
draw_layer(file, np.array([[-x2,0],[-x2,-y2],[-x1,-y2],[-x1,y2],[-x2,y2]]), 0.3, line_width, False)
draw_layer(file, np.array([[-x2,0],[-x2,-y2],[-x1,-y2],[-x1,y2],[-x2,y2]]), 0.7, line_width, True)
move_to(file, -x0+line_width/2, 0, 0.3)
draw_layer(file, np.array([[-x0,0],[-x0,-y2],[x0,-y2],[x0,y2],[-x0,y2]]), 0.3, line_width, False)
draw_layer(file, np.array([[-x0,0],[-x0,-y2],[x0,-y2],[x0,y2],[-x0,y2]]), 0.7, line_width, True)
move_to(file, x2-line_width/2, 0, 0.3)
draw_layer(file, np.array([[x2,0],[x2,y2],[x1,y2],[x1,-y2],[x2,-y2]]), 0.3, line_width, False)
draw_layer(file, np.array([[x2,0],[x2,y2],[x1,y2],[x1,-y2],[x2,-y2]]), 0.7, line_width, True)
move_to(file, -x2+line_width/2, -y2, 1.1)
soft_film(file, np.array([float(-x2),float(-y2)]), np.array([float(x2),float(y2)]), line_width, layer_height, z=1.1)

move_to(file, -x2+line_width/2, 0, 1.5)
for i in range (layer_count):
    xb = xbl[i]
    draw_layer(file, np.array([[-x2,0],[-x2,-y2],[-x1-xb,-y2],
                               [-x1-xb,y2],[-x2,y2]]), i*layer_height + 1.5, line_width, i%2)

move_to(file, x2-line_width/2, 0, 1.5)
for i in range (layer_count):
    xb = xbl[i]
    draw_layer(file, np.array([[x2,0],[x2,y2],[x1+xb,y2],
                               [x1+xb,-y2],[x2,-y2]]), i*layer_height + 1.5, line_width, i%2)

move_to(file, -x0+line_width/2, -y1, 1.5)
for i in range (layer_count-7):
    xb = xbl[i]
    draw_layer(file, np.array([[-x0+xb,0],[-x0+xb,-y2],[x0-xb,-y2],[x0-xb,y2],[-x0+xb,y2]]), 
               i*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
move_to(file, 0, 1.0, 1.5)
for i in range (4):
    xb = xbl[i+3]
    draw_layer(file, np.array([[0,0.8],[x0-xb,0.8],[x0-xb,y2],[-x0+xb,y2],[-x0+xb,0.8]]), 
               (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
move_to(file, 0, -1.0, 2.7)
for i in range (4):
    xb = xbl[i+3]
    draw_layer(file, np.array([[0,-0.8],[-x0+xb,-0.8],[-x0+xb,-y2],[x0-xb,-y2],[x0-xb,-0.8]]), 
               (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
move_to(file, 0, y2/2, 4.3)
for i in range (layer_count-7):
    xb = xbl[i+7]
    draw_layer(file, np.array([[-x0+xb,y2/2],[-x0+xb,-y2],[x0-xb,-y2],[x0-xb,y2],[-x0+xb,y2]]), 
               (i+layer_count-3)*layer_height + 1.5, line_width, i%2, extra_line=int(not i%2))
    
# side walls
xo = 1.2
move_to(file, x1+1.25+xo, -9.8, 1.5)
lines = []
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i%2==0:
        lines.append(f'G1 X{(x1+xo+xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{(x0-xo-xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
    else:
        lines.append(f'G1 X{(x0-xo-xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{(x1+xo+xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
with open(file, 'a') as f:
    f.writelines(lines)
    
move_to(file, x1+1.25+xo, 9.8, 1.5)
lines = []
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i%2==0:
        lines.append(f'G1 X{(x1+xo+xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{(x0-xo-xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
    else:
        lines.append(f'G1 X{(x0-xo-xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{(x1+xo+xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
with open(file, 'a') as f:
    f.writelines(lines)

move_to(file, -x1-1.25-xo, -9.8, 1.5)
lines = []
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i%2==0:
        lines.append(f'G1 X{-(x1+xo+xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{-(x0-xo-xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
    else:
        lines.append(f'G1 X{-(x0-xo-xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{-(x1+xo+xb):.3f} Y-9.8 Z{i*layer_height + 1.5:.3f}\n')
with open(file, 'a') as f:
    f.writelines(lines)
    
move_to(file, -x1-1.25-xo, 9.8, 1.5)
lines = []
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i%2==0:
        lines.append(f'G1 X{-(x1+xo+xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{-(x0-xo-xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
    else:
        lines.append(f'G1 X{-(x0-xo-xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
        lines.append(f'G1 X{-(x1+xo+xb):.3f} Y9.8 Z{i*layer_height + 1.5:.3f}\n')
with open(file, 'a') as f:
    f.writelines(lines)
    
        
writ_finish_lines(file)

# %%
mesh = 'single_60'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.17/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -12.8, 0)

xo = 0.4
x1 = 0.0
x2 = 13.0
w = line_width

theta = np.pi/3/2
k = np.tan(theta + 0.4*np.cos(theta)/4)

xbl = [np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)*k for i in range (layer_count)]
xsl = [np.sqrt(h**2-(h-layer_height/2-(layer_count-i)*layer_height)**2) for i in range (layer_count)]
xbl[0] = np.min([0.6, xbl[0]])

# bottom film
draw_layer(file, np.array([[-x2,0],[-x2,-10],[-(x1+xo),-10],[-(x1+xo),10],[-x2,10]]), 0.3, line_width, 0)
draw_layer(file, np.array([[-x2,0],[-x2,-10],[-(x1+xo),-10],[-(x1+xo),10],[-x2,10]]), 0.7, line_width, 1)

move_to(file, x2-w/2, 0, 0.3)
draw_layer(file, np.array([[x2,0],[x2,10],[(x1+xo),10],[(x1+xo),-10],[x2,-10]]), 0.3, line_width, 0)
draw_layer(file, np.array([[x2,0],[x2,10],[(x1+xo),10],[(x1+xo),-10],[x2,-10]]), 0.7, line_width, 1)

move_to(file, -(x2-w/2), -9.8, 1.1)

soft_film(file, np.array([-x2,-10.0]), np.array([x2,10.0]), line_width, layer_height, z=1.1)

# 2 full platforms
move_to(file, -x2+w/2, 0, 1.5)
for i in range (layer_count):
    # xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xb = xbl[i]
    draw_layer(file, np.array([[-x2,0],[-x2,-10],[-(x1+xo)-xb,-10],[-(x1+xo)-xb,10],[-x2,10]]), 
               i*layer_height + 1.5, line_width, i%2)
    
move_to(file, x2-w/2, 0, 1.5)
for i in range (layer_count):
    # xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xb = xbl[i]
    draw_layer(file, np.array([[x2,0],[x2,10],[(x1+xo)+xb,10],[(x1+xo)+xb,-10],[x2,-10]]), 
               i*layer_height + 1.5, line_width, i%2)

writ_finish_lines(file)

# %%
mesh = 'base_cross_new'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

file = '8.19/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -47.7, 0)

# bottom cross
draw_layer(file, np.array([[-48.2,0],[-48.2,-8],[-27.2,-8],[-27.2,8],[-48.2,8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[-48.2,0],[-48.2,-8],[-27.2,-8],[-27.2,8],[-48.2,8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, -26.1, 0, 0.3)
draw_layer(file, np.array([[-26.4,0],[-26.4,-8],[-0.4,-8],[-0.4,8],[-5.4,8],
                           [-5.4,13],[-21.4,13],[-21.4,8],[-26.4,8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[-26.4,0],[-26.4,-8],[-0.4,-8],[-0.4,8],[-5.4,8],
                           [-5.4,13],[-21.4,13],[-21.4,8],[-26.4,8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, 26.1, 0, 0.3)
draw_layer(file, np.array([[26.4,0],[26.4,8],[0.4,8],[0.4,-8],[5.4,-8],
                           [5.4,-13],[21.4,-13],[21.4,-8],[26.4,-8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[26.4,0],[26.4,8],[0.4,8],[0.4,-8],[5.4,-8],
                           [5.4,-13],[21.4,-13],[21.4,-8],[26.4,-8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, 47.7, 0, 0.3)
draw_layer(file, np.array([[48.2,0],[48.2,8],[27.2,8],[27.2,-8],[48.2,-8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[48.2,0],[48.2,8],[27.2,8],[27.2,-8],[48.2,-8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, -13.4, 13.8, 0.3)
draw_layer(file, np.array([[-13.4,13.8],[-5.4,13.8],[-5.4,34.8],
                           [-21.4,34.8],[-21.4,13.8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[-13.4,13.8],[-5.4,13.8],[-5.4,34.8],
                           [-21.4,34.8],[-21.4,13.8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, 13.4, -13.8, 0.3)
draw_layer(file, np.array([[13.4,-13.8],[5.4,-13.8],[5.4,-34.8],
                           [21.4,-34.8],[21.4,-13.8]]), 0.3, line_width, 0, extra_line=1)
draw_layer(file, np.array([[13.4,-13.8],[5.4,-13.8],[5.4,-34.8],
                           [21.4,-34.8],[21.4,-13.8]]), 0.7, line_width, 1, extra_line=1)

move_to(file, -47.7, 0, 1.1)
draw_layer(file, np.array([[-48.2,0],[-48.2,-8],[5.4,-8],[5.4,-34.8],[21.4,-34.8],[21.4,-8],[48.2,-8],[48.2,8],
                           [-5.4,8],[-5.4,34.8],[-21.4,34.8],[-21.4,8],[-48.2,8]]), 1.1, line_width, 1, extra_line=1)

# 4 full platforms
move_to(file, -47.7, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i < 4:
        draw_layer(file, np.array([[-48.2,0],[-48.2,-8],[-27.2-xb,-8],
                               [-27.2-xb,8],[-48.2,8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[-48.2,0],[-48.2,-8],[-27.2-xb,-8],
                               [-27.2-xb,8],[-48.2,8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, -13.4, 34.4, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    if i < 4:
        draw_layer(file, np.array([[-13.4,34.8],[-21.4,34.8],[-21.4,13.8+xb],
                               [-5.4,13.8+xb],[-5.4,34.8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[-13.4,34.8],[-21.4,34.8],[-21.4,13.8+xb],
                               [-5.4,13.8+xb],[-5.4,34.8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, 13.4, -34.4, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    xs = layer_height/2+i*layer_height
    if i < 4:
        draw_layer(file, np.array([[13.4,-34.8],[21.4,-34.8],[21.4,-13.8-xb],
                               [5.4,-13.8-xb],[5.4,-34.8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[13.4,-34.8],[21.4,-34.8],[21.4,-13.8-xb],
                               [5.4,-13.8-xb],[5.4,-34.8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, 47.7, 0, 1.5)
for i in range (layer_count):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    if i < 4:
        draw_layer(file, np.array([[48.2,0],[48.2,8],[27.2+xb,8],
                               [27.2+xb,-8],[48.2,-8]]), i*layer_height + 1.5, line_width, i%2, extra_line=1)
    else:
        draw_layer(file, np.array([[48.2,0],[48.2,8],[27.2+xb,8],
                               [27.2+xb,-8],[48.2,-8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
    
# 2 half platforms
move_to(file, -24.95, 0, 1.5)
for i in range (layer_count-7):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[-26.4+xb,0],[-26.4+xb,-8],[-0.4-xb,-8],[-0.4-xb,8],[-5.4,8],[-5.4,13-xb],
                               [-21.4,13-xb],[-21.4,8],[-26.4+xb,8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, -14.8, 1.4, 2.7)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[-14.6,1.2],[-14.6,13-xb],[-21.4,13-xb],[-21.4,8],[-26.4+xb,8],
                               [-26.4+xb,1.2]]), (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, -12.0, 1.4, 2.7)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[-12.2,1.2],[-0.4-xb,1.2],[-0.4-xb,8],[-5.4,8],[-5.4,13-xb],
                               [-12.2,13-xb]]), (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, -13.4, -1.4, 2.7)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[-13.4,-1.2],[-26.4+xb,-1.2],[-26.4+xb,-8],[-0.4-xb,-8],
                               [-0.4-xb,-1.2]]), (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=0)
    
move_to(file, 24.95, 0, 1.5)
for i in range (layer_count-7):
    xb = np.sqrt(h**2-(h-layer_height/2-i*layer_height)**2)
    draw_layer(file, np.array([[26.4-xb,0],[26.4-xb,8],[0.4+xb,8],[0.4+xb,-8],[5.4,-8],[5.4,-13+xb],
                               [21.4,-13+xb],[21.4,-8],[26.4-xb,-8]]), i*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, 14.8, -1.4, 2.7)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[14.6,-1.2],[14.6,-13+xb],[21.4,-13+xb],[21.4,-8],[26.4-xb,-8],
                               [26.4-xb,-1.2]]), (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, 12.0, -1.4, 2.7)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[12.2,-1.2],[0.4+xb,-1.2],[0.4+xb,-8],[5.4,-8],[5.4,-13+xb],
                               [12.2,-13+xb]]), (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=0)
move_to(file, 13.4, 1.4, 2.7)
for i in range (4):
    xb = np.sqrt(h**2-(h-layer_height/2-(i+layer_count-7)*layer_height)**2)
    draw_layer(file, np.array([[13.4,1.2],[26.4-xb,1.2],[26.4-xb,8],[0.4+xb,8],
                               [0.4+xb,1.2]]), (i+layer_count-7)*layer_height + 1.5, line_width, i%2, extra_line=0)
    

    

writ_finish_lines(file)

# %%
theta + 0.8*np.cos(theta)/4
# Out:
# 0.9268195196347578

# %%
theta
# Out:
# 0.7853981633974483

# %%
np.tan
