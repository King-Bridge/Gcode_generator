# %%
import numpy as np

from gcode_polygon import *
from gcode_origami import soft_film

# %%
mesh = 'miura_base'
layer_height = 0.4
line_width = 0.4
height = 4
h = height
layer_count = int(height/layer_height)

g = 0.4
k = np.sqrt(3)

file = '8.19/'+mesh+'.gcode'
write_header_lines(file, layer_height, line_width, layer_count, mesh, -25+g,15*k-g)

# bottom layer

draw_layer(file, np.array([[-25+g,15*k-g],[-25+g,-5*k+g],[-15-g/k,-5*k+g],[-5-g*2/k,5*k],[-15-g/k,15*k-g]]), 0.3, line_width, 0)
move_to(file,-25+g,-5*k-g,0.3)
draw_layer(file, np.array([[-25+g,-5*k-g],[-25+g,-25*k+g],[-5-k*g,-25*k+g],[-15-k/g,-5*k-g]]), 0.3, line_width, 0)



writ_finish_lines(file)
